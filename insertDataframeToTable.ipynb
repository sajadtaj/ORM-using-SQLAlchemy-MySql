# %%
import yfinance as yf
import numpy    as np
import pandas   as pd
import datetime
from sqlalchemy import create_engine,Column,Integer,String,DateTime,ForeignKey,Float,BIGINT
from typing import List,Optional
from sqlalchemy.orm import DeclarativeBase
from sqlalchemy.orm import Mapped
from sqlalchemy.orm import mapped_column
from sqlalchemy.orm import relationship
from sqlalchemy.orm import Session
from sqlalchemy.orm import sessionmaker

# %%
class Base(DeclarativeBase):
        pass

# Create Models : Table
class BTC_UCD(Base):
    __tablename__ = 'BTC_UCD'
    id = Column(Integer, primary_key=True)
    Open     = Column(Float)
    High     = Column(Float)
    Low      = Column(Float)
    Close    = Column(Float)
    AdjClose = Column(Float)
    Volume   = Column(BIGINT)
    date     = Column(DateTime)

    def __repr__(self):
        return f"< BTC_UCD(date='{self.date}', Close='{self.Close}')>"

# %% [markdown]
# ## Create Engine

# %%
engine = create_engine("mysql+pymysql://root:tajedin@localhost:3306/Test_Grafana", echo=False)
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)

# %% [markdown]
# ## Create Table

# %%
Base.metadata.create_all(engine)

# %%
# BTC-USD = yf.download(tickers='BTC-USD', start="2020-01-01", end="2024-03-29",ignore_tz=True)
# BTC_USD.to_pickle('./BTC_UCD.pickle')
BTC_USD_df =pd.read_pickle('./Data/BTC_UCD.pickle')

BTC_USD_df
# Out:
#                     Open          High           Low         Close  \
# Date
# 2015-01-01    320.434998    320.434998    314.002991    314.248993
# 2015-01-02    314.079010    315.838989    313.565002    315.032013
# 2015-01-03    314.846008    315.149994    281.082001    281.082001
# 2015-01-04    281.145996    287.230011    257.612000    264.195007
# 2015-01-05    265.084015    278.341003    265.084015    274.473999
# ...                  ...           ...           ...           ...
# 2024-03-24  64070.753906  67622.757812  63825.851562  67234.171875
# 2024-03-25  67234.093750  71162.593750  66414.835938  69958.812500
# 2024-03-26  69931.328125  71535.742188  69335.609375  69987.835938
# 2024-03-27  69991.898438  71727.687500  68381.929688  69455.343750
# 2024-03-28  69452.773438  71546.023438  68895.507812  70744.953125
#
#                Adj Close       Volume
# Date
# 2015-01-01    314.248993      8036550
# 2015-01-02    315.032013      7860650
# 2015-01-03    281.082001     33054400
# 2015-01-04    264.195007     55629100
# 2015-01-05    274.473999     43962800
# ...                  ...          ...
# 2024-03-24  67234.171875  27206630673
# 2024-03-25  69958.812500  42700139523
# 2024-03-26  69987.835938  36010437368
# 2024-03-27  69455.343750  40827113309
# 2024-03-28  70744.953125  34374900617
#
# [3375 rows x 6 columns]

# %% [markdown]
# ## Iterate and Create Objects:
# Alternatively, you can iterate through the DataFrame and create individual model objects based on each row:

# %%
data_objects = []
for index, row in BTC_USD_df.iterrows():
    user_object = BTC_UCD(
                    Open     = row['Open'],
                    High     = row['High'],
                    Low      = row['Low'],
                    Close    = row['Close'],
                    AdjClose = row['Adj Close'],
                    Volume   = row['Volume'],
                    date     = index
        )  # Create object with row values
    data_objects.append(user_object)

# %%
data_objects
# Out:
# [< BTC_UCD(date='2015-01-01 00:00:00', Close='314.2489929199219')>,
#  < BTC_UCD(date='2015-01-02 00:00:00', Close='315.0320129394531')>,
#  < BTC_UCD(date='2015-01-03 00:00:00', Close='281.0820007324219')>,
#  < BTC_UCD(date='2015-01-04 00:00:00', Close='264.19500732421875')>,
#  < BTC_UCD(date='2015-01-05 00:00:00', Close='274.4739990234375')>,
#  < BTC_UCD(date='2015-01-06 00:00:00', Close='286.1889953613281')>,
#  < BTC_UCD(date='2015-01-07 00:00:00', Close='294.3370056152344')>,
#  < BTC_UCD(date='2015-01-08 00:00:00', Close='283.3489990234375')>,
#  < BTC_UCD(date='2015-01-09 00:00:00', Close='290.4079895019531')>,
#  < BTC_UCD(date='2015-01-10 00:00:00', Close='274.7959899902344')>,
#  < BTC_UCD(date='2015-01-11 00:00:00', Close='265.6600036621094')>,
#  < BTC_UCD(date='2015-01-12 00:00:00', Close='267.7959899902344')>,
#  < BTC_UCD(date='2015-01-13 00:00:00', Close='225.86099243164062')>,
#  < BTC_UCD(date='2015-01-14 00:00:00', Close='178.10299682617188')>,
#  < BTC_UCD(date='2015-01-15 00:00:00', Close='209.843994140625')>,
#  < BTC_UCD(date='2015-01-16 00:00:00', Close='208.0970001220703')>,
#  < BTC_UCD(date='2015-01-17 00:00:00', Close='199.25999450683594')>,
#  < BTC_UCD(date='2015-01-18 00:00:00', Close='210.33900451660156')>,
#  < BTC_UCD(date='2015-01-19 00:00:00', Close='214.86099243164062')>,
#  < BTC_UCD(date='2015-01-20 00:00:00', Close='211.31500244140625')>,
#  < BTC_UCD(date='2015-01-21 00:00:00', Close='226.89700317382812')>,
#  < BTC_UCD(date='2015-01-22 00:00:00', Close='233.406005859375')>,
#  < BTC_UCD(date='2015-01-23 00:00:00', Close='232.87899780273438')>,
#  < BTC_UCD(date='2015-01-24 00:00:00', Close='247.8470001220703')>,
#  < BTC_UCD(date='2015-01-25 00:00:00', Close='253.71800231933594')>,
#  < BTC_UCD(date='2015-01-26 00:00:00', Close='273.4729919433594')>,
#  < BTC_UCD(date='2015-01-27 00:00:00', Close='263.4750061035156')>,
#  < BTC_UCD(date='2015-01-28 00:00:00', Close='233.9149932861328')>,
#  < BTC_UCD(date='2015-01-29 00:00:00', Close='233.51300048828125')>,
#  < BTC_UCD(date='2015-01-30 00:00:00', Close='226.4250030517578')>,
#  < BTC_UCD(date='2015-01-31 00:00:00', Close='217.46400451660156')>,
#  < BTC_UCD(date='2015-02-01 00:00:00', Close='226.9720001220703')>,
#  < BTC_UCD(date='2015-02-02 00:00:00', Close='238.22900390625')>,
#  < BTC_UCD(date='2015-02-03 00:00:00', Close='227.26800537109375')>,
#  < BTC_UCD(date='2015-02-04 00:00:00', Close='226.85299682617188')>,
#  < BTC_UCD(date='2015-02-05 00:00:00', Close='217.11099243164062')>,
#  < BTC_UCD(date='2015-02-06 00:00:00', Close='222.26600646972656')>,
#  < BTC_UCD(date='2015-02-07 00:00:00', Close='227.75399780273438')>,
#  < BTC_UCD(date='2015-02-08 00:00:00', Close='223.41200256347656')>,
#  < BTC_UCD(date='2015-02-09 00:00:00', Close='220.11000061035156')>,
#  < BTC_UCD(date='2015-02-10 00:00:00', Close='219.83900451660156')>,
#  < BTC_UCD(date='2015-02-11 00:00:00', Close='219.18499755859375')>,
#  < BTC_UCD(date='2015-02-12 00:00:00', Close='221.76400756835938')>,
#  < BTC_UCD(date='2015-02-13 00:00:00', Close='235.427001953125')>,
#  < BTC_UCD(date='2015-02-14 00:00:00', Close='257.3210144042969')>,
#  < BTC_UCD(date='2015-02-15 00:00:00', Close='234.8249969482422')>,
#  < BTC_UCD(date='2015-02-16 00:00:00', Close='233.84300231933594')>,
#  < BTC_UCD(date='2015-02-17 00:00:00', Close='243.61000061035156')>,
#  < BTC_UCD(date='2015-02-18 00:00:00', Close='236.3260040283203')>,
#  < BTC_UCD(date='2015-02-19 00:00:00', Close='240.2830047607422')>,
#  < BTC_UCD(date='2015-02-20 00:00:00', Close='243.7790069580078')>,
#  < BTC_UCD(date='2015-02-21 00:00:00', Close='244.53399658203125')>,
#  < BTC_UCD(date='2015-02-22 00:00:00', Close='235.9770050048828')>,
#  < BTC_UCD(date='2015-02-23 00:00:00', Close='238.89199829101562')>,
#  < BTC_UCD(date='2015-02-24 00:00:00', Close='238.73500061035156')>,
#  < BTC_UCD(date='2015-02-25 00:00:00', Close='237.47000122070312')>,
#  < BTC_UCD(date='2015-02-26 00:00:00', Close='236.42599487304688')>,
#  < BTC_UCD(date='2015-02-27 00:00:00', Close='253.8280029296875')>,
#  < BTC_UCD(date='2015-02-28 00:00:00', Close='254.26300048828125')>,
#  < BTC_UCD(date='2015-03-01 00:00:00', Close='260.2019958496094')>,
#  < BTC_UCD(date='2015-03-02 00:00:00', Close='275.6700134277344')>,
#  < BTC_UCD(date='2015-03-03 00:00:00', Close='281.7019958496094')>,
#  < BTC_UCD(date='2015-03-04 00:00:00', Close='273.0920104980469')>,
#  < BTC_UCD(date='2015-03-05 00:00:00', Close='276.1780090332031')>,
#  < BTC_UCD(date='2015-03-06 00:00:00', Close='272.7229919433594')>,
#  < BTC_UCD(date='2015-03-07 00:00:00', Close='276.260986328125')>,
#  < BTC_UCD(date='2015-03-08 00:00:00', Close='274.35400390625')>,
#  < BTC_UCD(date='2015-03-09 00:00:00', Close='289.60699462890625')>,
#  < BTC_UCD(date='2015-03-10 00:00:00', Close='291.760009765625')>,
#  < BTC_UCD(date='2015-03-11 00:00:00', Close='296.3789978027344')>,
#  < BTC_UCD(date='2015-03-12 00:00:00', Close='294.35400390625')>,
#  < BTC_UCD(date='2015-03-13 00:00:00', Close='285.3370056152344')>,
#  < BTC_UCD(date='2015-03-14 00:00:00', Close='281.885009765625')>,
#  < BTC_UCD(date='2015-03-15 00:00:00', Close='286.39300537109375')>,
#  < BTC_UCD(date='2015-03-16 00:00:00', Close='290.5929870605469')>,
#  < BTC_UCD(date='2015-03-17 00:00:00', Close='285.5050048828125')>,
#  < BTC_UCD(date='2015-03-18 00:00:00', Close='256.29901123046875')>,
#  < BTC_UCD(date='2015-03-19 00:00:00', Close='260.9280090332031')>,
#  < BTC_UCD(date='2015-03-20 00:00:00', Close='261.7489929199219')>,
#  < BTC_UCD(date='2015-03-21 00:00:00', Close='260.0249938964844')>,
#  < BTC_UCD(date='2015-03-22 00:00:00', Close='267.9599914550781')>,
#  < BTC_UCD(date='2015-03-23 00:00:00', Close='266.739990234375')>,
#  < BTC_UCD(date='2015-03-24 00:00:00', Close='245.59500122070312')>,
#  < BTC_UCD(date='2015-03-25 00:00:00', Close='246.19700622558594')>,
#  < BTC_UCD(date='2015-03-26 00:00:00', Close='248.53199768066406')>,
#  < BTC_UCD(date='2015-03-27 00:00:00', Close='247.0290069580078')>,
#  < BTC_UCD(date='2015-03-28 00:00:00', Close='252.79800415039062')>,
#  < BTC_UCD(date='2015-03-29 00:00:00', Close='242.71299743652344')>,
#  < BTC_UCD(date='2015-03-30 00:00:00', Close='247.5260009765625')>,
#  < BTC_UCD(date='2015-03-31 00:00:00', Close='244.2239990234375')>,
#  < BTC_UCD(date='2015-04-01 00:00:00', Close='247.27200317382812')>,
#  < BTC_UCD(date='2015-04-02 00:00:00', Close='253.0050048828125')>,
#  < BTC_UCD(date='2015-04-03 00:00:00', Close='254.32200622558594')>,
#  < BTC_UCD(date='2015-04-04 00:00:00', Close='253.69700622558594')>,
#  < BTC_UCD(date='2015-04-05 00:00:00', Close='260.5979919433594')>,
#  < BTC_UCD(date='2015-04-06 00:00:00', Close='255.49200439453125')>,
#  < BTC_UCD(date='2015-04-07 00:00:00', Close='253.17999267578125')>,
#  < BTC_UCD(date='2015-04-08 00:00:00', Close='245.02200317382812')>,
#  < BTC_UCD(date='2015-04-09 00:00:00', Close='243.67599487304688')>,
#  < BTC_UCD(date='2015-04-10 00:00:00', Close='236.07200622558594')>,
#  < BTC_UCD(date='2015-04-11 00:00:00', Close='236.552001953125')>,
#  < BTC_UCD(date='2015-04-12 00:00:00', Close='236.1529998779297')>,
#  < BTC_UCD(date='2015-04-13 00:00:00', Close='224.58700561523438')>,
#  < BTC_UCD(date='2015-04-14 00:00:00', Close='219.15899658203125')>,
#  < BTC_UCD(date='2015-04-15 00:00:00', Close='223.83299255371094')>,
#  < BTC_UCD(date='2015-04-16 00:00:00', Close='228.572998046875')>,
#  < BTC_UCD(date='2015-04-17 00:00:00', Close='222.8820037841797')>,
#  < BTC_UCD(date='2015-04-18 00:00:00', Close='223.3560028076172')>,
#  < BTC_UCD(date='2015-04-19 00:00:00', Close='222.60000610351562')>,
#  < BTC_UCD(date='2015-04-20 00:00:00', Close='224.62600708007812')>,
#  < BTC_UCD(date='2015-04-21 00:00:00', Close='235.2689971923828')>,
#  < BTC_UCD(date='2015-04-22 00:00:00', Close='234.17599487304688')>,
#  < BTC_UCD(date='2015-04-23 00:00:00', Close='236.46200561523438')>,
#  < BTC_UCD(date='2015-04-24 00:00:00', Close='231.26800537109375')>,
#  < BTC_UCD(date='2015-04-25 00:00:00', Close='226.38999938964844')>,
#  < BTC_UCD(date='2015-04-26 00:00:00', Close='219.42999267578125')>,
#  < BTC_UCD(date='2015-04-27 00:00:00', Close='229.28599548339844')>,
#  < BTC_UCD(date='2015-04-28 00:00:00', Close='225.85499572753906')>,
#  < BTC_UCD(date='2015-04-29 00:00:00', Close='225.80799865722656')>,
#  < BTC_UCD(date='2015-04-30 00:00:00', Close='236.14500427246094')>,
#  < BTC_UCD(date='2015-05-01 00:00:00', Close='232.07899475097656')>,
#  < BTC_UCD(date='2015-05-02 00:00:00', Close='234.92999267578125')>,
#  < BTC_UCD(date='2015-05-03 00:00:00', Close='240.35800170898438')>,
#  < BTC_UCD(date='2015-05-04 00:00:00', Close='239.01800537109375')>,
#  < BTC_UCD(date='2015-05-05 00:00:00', Close='236.12100219726562')>,
#  < BTC_UCD(date='2015-05-06 00:00:00', Close='229.78199768066406')>,
#  < BTC_UCD(date='2015-05-07 00:00:00', Close='237.33399963378906')>,
#  < BTC_UCD(date='2015-05-08 00:00:00', Close='243.86300659179688')>,
#  < BTC_UCD(date='2015-05-09 00:00:00', Close='241.83200073242188')>,
#  < BTC_UCD(date='2015-05-10 00:00:00', Close='240.29600524902344')>,
#  < BTC_UCD(date='2015-05-11 00:00:00', Close='242.1580047607422')>,
#  < BTC_UCD(date='2015-05-12 00:00:00', Close='241.11199951171875')>,
#  < BTC_UCD(date='2015-05-13 00:00:00', Close='236.3769989013672')>,
#  < BTC_UCD(date='2015-05-14 00:00:00', Close='236.9290008544922')>,
#  < BTC_UCD(date='2015-05-15 00:00:00', Close='237.60499572753906')>,
#  < BTC_UCD(date='2015-05-16 00:00:00', Close='236.1529998779297')>,
#  < BTC_UCD(date='2015-05-17 00:00:00', Close='236.802001953125')>,
#  < BTC_UCD(date='2015-05-18 00:00:00', Close='233.1280059814453')>,
#  < BTC_UCD(date='2015-05-19 00:00:00', Close='231.94700622558594')>,
#  < BTC_UCD(date='2015-05-20 00:00:00', Close='234.01800537109375')>,
#  < BTC_UCD(date='2015-05-21 00:00:00', Close='235.343994140625')>,
#  < BTC_UCD(date='2015-05-22 00:00:00', Close='240.34800720214844')>,
#  < BTC_UCD(date='2015-05-23 00:00:00', Close='238.8719940185547')>,
#  < BTC_UCD(date='2015-05-24 00:00:00', Close='240.9530029296875')>,
#  < BTC_UCD(date='2015-05-25 00:00:00', Close='237.11000061035156')>,
#  < BTC_UCD(date='2015-05-26 00:00:00', Close='237.11599731445312')>,
#  < BTC_UCD(date='2015-05-27 00:00:00', Close='237.2830047607422')>,
#  < BTC_UCD(date='2015-05-28 00:00:00', Close='237.4080047607422')>,
#  < BTC_UCD(date='2015-05-29 00:00:00', Close='237.0959930419922')>,
#  < BTC_UCD(date='2015-05-30 00:00:00', Close='233.34500122070312')>,
#  < BTC_UCD(date='2015-05-31 00:00:00', Close='230.19000244140625')>,
#  < BTC_UCD(date='2015-06-01 00:00:00', Close='222.92599487304688')>,
#  < BTC_UCD(date='2015-06-02 00:00:00', Close='225.80299377441406')>,
#  < BTC_UCD(date='2015-06-03 00:00:00', Close='225.87399291992188')>,
#  < BTC_UCD(date='2015-06-04 00:00:00', Close='224.32400512695312')>,
#  < BTC_UCD(date='2015-06-05 00:00:00', Close='224.95199584960938')>,
#  < BTC_UCD(date='2015-06-06 00:00:00', Close='225.61900329589844')>,
#  < BTC_UCD(date='2015-06-07 00:00:00', Close='222.88099670410156')>,
#  < BTC_UCD(date='2015-06-08 00:00:00', Close='228.48899841308594')>,
#  < BTC_UCD(date='2015-06-09 00:00:00', Close='229.04800415039062')>,
#  < BTC_UCD(date='2015-06-10 00:00:00', Close='228.80299377441406')>,
#  < BTC_UCD(date='2015-06-11 00:00:00', Close='229.7050018310547')>,
#  < BTC_UCD(date='2015-06-12 00:00:00', Close='229.98199462890625')>,
#  < BTC_UCD(date='2015-06-13 00:00:00', Close='232.40199279785156')>,
#  < BTC_UCD(date='2015-06-14 00:00:00', Close='233.54299926757812')>,
#  < BTC_UCD(date='2015-06-15 00:00:00', Close='236.822998046875')>,
#  < BTC_UCD(date='2015-06-16 00:00:00', Close='250.89500427246094')>,
#  < BTC_UCD(date='2015-06-17 00:00:00', Close='249.28399658203125')>,
#  < BTC_UCD(date='2015-06-18 00:00:00', Close='249.0070037841797')>,
#  < BTC_UCD(date='2015-06-19 00:00:00', Close='244.6060028076172')>,
#  < BTC_UCD(date='2015-06-20 00:00:00', Close='245.21200561523438')>,
#  < BTC_UCD(date='2015-06-21 00:00:00', Close='243.94400024414062')>,
#  < BTC_UCD(date='2015-06-22 00:00:00', Close='246.99000549316406')>,
#  < BTC_UCD(date='2015-06-23 00:00:00', Close='244.29600524902344')>,
#  < BTC_UCD(date='2015-06-24 00:00:00', Close='240.51499938964844')>,
#  < BTC_UCD(date='2015-06-25 00:00:00', Close='242.7989959716797')>,
#  < BTC_UCD(date='2015-06-26 00:00:00', Close='243.593994140625')>,
#  < BTC_UCD(date='2015-06-27 00:00:00', Close='250.99000549316406')>,
#  < BTC_UCD(date='2015-06-28 00:00:00', Close='249.01100158691406')>,
#  < BTC_UCD(date='2015-06-29 00:00:00', Close='257.0639953613281')>,
#  < BTC_UCD(date='2015-06-30 00:00:00', Close='263.0719909667969')>,
#  < BTC_UCD(date='2015-07-01 00:00:00', Close='258.6210021972656')>,
#  < BTC_UCD(date='2015-07-02 00:00:00', Close='255.41200256347656')>,
#  < BTC_UCD(date='2015-07-03 00:00:00', Close='256.33599853515625')>,
#  < BTC_UCD(date='2015-07-04 00:00:00', Close='260.885986328125')>,
#  < BTC_UCD(date='2015-07-05 00:00:00', Close='271.9129943847656')>,
#  < BTC_UCD(date='2015-07-06 00:00:00', Close='269.0299987792969')>,
#  < BTC_UCD(date='2015-07-07 00:00:00', Close='266.2070007324219')>,
#  < BTC_UCD(date='2015-07-08 00:00:00', Close='270.7850036621094')>,
#  < BTC_UCD(date='2015-07-09 00:00:00', Close='269.2279968261719')>,
#  < BTC_UCD(date='2015-07-10 00:00:00', Close='284.8940124511719')>,
#  < BTC_UCD(date='2015-07-11 00:00:00', Close='293.114990234375')>,
#  < BTC_UCD(date='2015-07-12 00:00:00', Close='310.86700439453125')>,
#  < BTC_UCD(date='2015-07-13 00:00:00', Close='292.0539855957031')>,
#  < BTC_UCD(date='2015-07-14 00:00:00', Close='287.4639892578125')>,
#  < BTC_UCD(date='2015-07-15 00:00:00', Close='285.8290100097656')>,
#  < BTC_UCD(date='2015-07-16 00:00:00', Close='278.0889892578125')>,
#  < BTC_UCD(date='2015-07-17 00:00:00', Close='279.47198486328125')>,
#  < BTC_UCD(date='2015-07-18 00:00:00', Close='274.9010009765625')>,
#  < BTC_UCD(date='2015-07-19 00:00:00', Close='273.614013671875')>,
#  < BTC_UCD(date='2015-07-20 00:00:00', Close='278.9809875488281')>,
#  < BTC_UCD(date='2015-07-21 00:00:00', Close='275.8330078125')>,
#  < BTC_UCD(date='2015-07-22 00:00:00', Close='277.22198486328125')>,
#  < BTC_UCD(date='2015-07-23 00:00:00', Close='276.04901123046875')>,
#  < BTC_UCD(date='2015-07-24 00:00:00', Close='288.27801513671875')>,
#  < BTC_UCD(date='2015-07-25 00:00:00', Close='288.6969909667969')>,
#  < BTC_UCD(date='2015-07-26 00:00:00', Close='292.6860046386719')>,
#  < BTC_UCD(date='2015-07-27 00:00:00', Close='293.6239929199219')>,
#  < BTC_UCD(date='2015-07-28 00:00:00', Close='294.427001953125')>,
#  < BTC_UCD(date='2015-07-29 00:00:00', Close='289.5899963378906')>,
#  < BTC_UCD(date='2015-07-30 00:00:00', Close='287.72198486328125')>,
#  < BTC_UCD(date='2015-07-31 00:00:00', Close='284.6499938964844')>,
#  < BTC_UCD(date='2015-08-01 00:00:00', Close='281.60101318359375')>,
#  < BTC_UCD(date='2015-08-02 00:00:00', Close='282.614013671875')>,
#  < BTC_UCD(date='2015-08-03 00:00:00', Close='281.22698974609375')>,
#  < BTC_UCD(date='2015-08-04 00:00:00', Close='285.2179870605469')>,
#  < BTC_UCD(date='2015-08-05 00:00:00', Close='281.8819885253906')>,
#  < BTC_UCD(date='2015-08-06 00:00:00', Close='278.5769958496094')>,
#  < BTC_UCD(date='2015-08-07 00:00:00', Close='279.5849914550781')>,
#  < BTC_UCD(date='2015-08-08 00:00:00', Close='260.99700927734375')>,
#  < BTC_UCD(date='2015-08-09 00:00:00', Close='265.0830078125')>,
#  < BTC_UCD(date='2015-08-10 00:00:00', Close='264.4700012207031')>,
#  < BTC_UCD(date='2015-08-11 00:00:00', Close='270.385986328125')>,
#  < BTC_UCD(date='2015-08-12 00:00:00', Close='266.3760070800781')>,
#  < BTC_UCD(date='2015-08-13 00:00:00', Close='264.0799865722656')>,
#  < BTC_UCD(date='2015-08-14 00:00:00', Close='265.67999267578125')>,
#  < BTC_UCD(date='2015-08-15 00:00:00', Close='261.5509948730469')>,
#  < BTC_UCD(date='2015-08-16 00:00:00', Close='258.5069885253906')>,
#  < BTC_UCD(date='2015-08-17 00:00:00', Close='257.97601318359375')>,
#  < BTC_UCD(date='2015-08-18 00:00:00', Close='211.07899475097656')>,
#  < BTC_UCD(date='2015-08-19 00:00:00', Close='226.6840057373047')>,
#  < BTC_UCD(date='2015-08-20 00:00:00', Close='235.35000610351562')>,
#  < BTC_UCD(date='2015-08-21 00:00:00', Close='232.56900024414062')>,
#  < BTC_UCD(date='2015-08-22 00:00:00', Close='230.38999938964844')>,
#  < BTC_UCD(date='2015-08-23 00:00:00', Close='228.16900634765625')>,
#  < BTC_UCD(date='2015-08-24 00:00:00', Close='210.4949951171875')>,
#  < BTC_UCD(date='2015-08-25 00:00:00', Close='221.60899353027344')>,
#  < BTC_UCD(date='2015-08-26 00:00:00', Close='225.83099365234375')>,
#  < BTC_UCD(date='2015-08-27 00:00:00', Close='224.7689971923828')>,
#  < BTC_UCD(date='2015-08-28 00:00:00', Close='231.39599609375')>,
#  < BTC_UCD(date='2015-08-29 00:00:00', Close='229.77999877929688')>,
#  < BTC_UCD(date='2015-08-30 00:00:00', Close='228.76100158691406')>,
#  < BTC_UCD(date='2015-08-31 00:00:00', Close='230.05599975585938')>,
#  < BTC_UCD(date='2015-09-01 00:00:00', Close='228.12100219726562')>,
#  < BTC_UCD(date='2015-09-02 00:00:00', Close='229.28399658203125')>,
#  < BTC_UCD(date='2015-09-03 00:00:00', Close='227.18299865722656')>,
#  < BTC_UCD(date='2015-09-04 00:00:00', Close='230.29800415039062')>,
#  < BTC_UCD(date='2015-09-05 00:00:00', Close='235.0189971923828')>,
#  < BTC_UCD(date='2015-09-06 00:00:00', Close='239.83999633789062')>,
#  < BTC_UCD(date='2015-09-07 00:00:00', Close='239.8470001220703')>,
#  < BTC_UCD(date='2015-09-08 00:00:00', Close='243.60699462890625')>,
#  < BTC_UCD(date='2015-09-09 00:00:00', Close='238.16799926757812')>,
#  < BTC_UCD(date='2015-09-10 00:00:00', Close='238.4770050048828')>,
#  < BTC_UCD(date='2015-09-11 00:00:00', Close='240.10699462890625')>,
#  < BTC_UCD(date='2015-09-12 00:00:00', Close='235.22900390625')>,
#  < BTC_UCD(date='2015-09-13 00:00:00', Close='230.51199340820312')>,
#  < BTC_UCD(date='2015-09-14 00:00:00', Close='230.6439971923828')>,
#  < BTC_UCD(date='2015-09-15 00:00:00', Close='230.3040008544922')>,
#  < BTC_UCD(date='2015-09-16 00:00:00', Close='229.09100341796875')>,
#  < BTC_UCD(date='2015-09-17 00:00:00', Close='229.80999755859375')>,
#  < BTC_UCD(date='2015-09-18 00:00:00', Close='232.97500610351562')>,
#  < BTC_UCD(date='2015-09-19 00:00:00', Close='231.4929962158203')>,
#  < BTC_UCD(date='2015-09-20 00:00:00', Close='231.21200561523438')>,
#  < BTC_UCD(date='2015-09-21 00:00:00', Close='227.0850067138672')>,
#  < BTC_UCD(date='2015-09-22 00:00:00', Close='230.6179962158203')>,
#  < BTC_UCD(date='2015-09-23 00:00:00', Close='230.2830047607422')>,
#  < BTC_UCD(date='2015-09-24 00:00:00', Close='234.5290069580078')>,
#  < BTC_UCD(date='2015-09-25 00:00:00', Close='235.1439971923828')>,
#  < BTC_UCD(date='2015-09-26 00:00:00', Close='234.33999633789062')>,
#  < BTC_UCD(date='2015-09-27 00:00:00', Close='232.7570037841797')>,
#  < BTC_UCD(date='2015-09-28 00:00:00', Close='239.14199829101562')>,
#  < BTC_UCD(date='2015-09-29 00:00:00', Close='236.68699645996094')>,
#  < BTC_UCD(date='2015-09-30 00:00:00', Close='236.05999755859375')>,
#  < BTC_UCD(date='2015-10-01 00:00:00', Close='237.5489959716797')>,
#  < BTC_UCD(date='2015-10-02 00:00:00', Close='237.29299926757812')>,
#  < BTC_UCD(date='2015-10-03 00:00:00', Close='238.72999572753906')>,
#  < BTC_UCD(date='2015-10-04 00:00:00', Close='238.25900268554688')>,
#  < BTC_UCD(date='2015-10-05 00:00:00', Close='240.38299560546875')>,
#  < BTC_UCD(date='2015-10-06 00:00:00', Close='246.06300354003906')>,
#  < BTC_UCD(date='2015-10-07 00:00:00', Close='242.968994140625')>,
#  < BTC_UCD(date='2015-10-08 00:00:00', Close='242.3040008544922')>,
#  < BTC_UCD(date='2015-10-09 00:00:00', Close='243.93099975585938')>,
#  < BTC_UCD(date='2015-10-10 00:00:00', Close='244.9409942626953')>,
#  < BTC_UCD(date='2015-10-11 00:00:00', Close='247.0500030517578')>,
#  < BTC_UCD(date='2015-10-12 00:00:00', Close='245.30799865722656')>,
#  < BTC_UCD(date='2015-10-13 00:00:00', Close='249.50799560546875')>,
#  < BTC_UCD(date='2015-10-14 00:00:00', Close='251.98899841308594')>,
#  < BTC_UCD(date='2015-10-15 00:00:00', Close='254.32000732421875')>,
#  < BTC_UCD(date='2015-10-16 00:00:00', Close='262.8689880371094')>,
#  < BTC_UCD(date='2015-10-17 00:00:00', Close='270.6400146484375')>,
#  < BTC_UCD(date='2015-10-18 00:00:00', Close='261.64300537109375')>,
#  < BTC_UCD(date='2015-10-19 00:00:00', Close='263.43701171875')>,
#  < BTC_UCD(date='2015-10-20 00:00:00', Close='269.4630126953125')>,
#  < BTC_UCD(date='2015-10-21 00:00:00', Close='266.2720031738281')>,
#  < BTC_UCD(date='2015-10-22 00:00:00', Close='274.02301025390625')>,
#  < BTC_UCD(date='2015-10-23 00:00:00', Close='276.4960021972656')>,
#  < BTC_UCD(date='2015-10-24 00:00:00', Close='281.65399169921875')>,
#  < BTC_UCD(date='2015-10-25 00:00:00', Close='283.67999267578125')>,
#  < BTC_UCD(date='2015-10-26 00:00:00', Close='285.29998779296875')>,
#  < BTC_UCD(date='2015-10-27 00:00:00', Close='293.7879943847656')>,
#  < BTC_UCD(date='2015-10-28 00:00:00', Close='304.6180114746094')>,
#  < BTC_UCD(date='2015-10-29 00:00:00', Close='313.8550109863281')>,
#  < BTC_UCD(date='2015-10-30 00:00:00', Close='328.0150146484375')>,
#  < BTC_UCD(date='2015-10-31 00:00:00', Close='314.1659851074219')>,
#  < BTC_UCD(date='2015-11-01 00:00:00', Close='325.4309997558594')>,
#  < BTC_UCD(date='2015-11-02 00:00:00', Close='361.1889953613281')>,
#  < BTC_UCD(date='2015-11-03 00:00:00', Close='403.4169921875')>,
#  < BTC_UCD(date='2015-11-04 00:00:00', Close='411.56298828125')>,
#  < BTC_UCD(date='2015-11-05 00:00:00', Close='386.35400390625')>,
#  < BTC_UCD(date='2015-11-06 00:00:00', Close='374.4700012207031')>,
#  < BTC_UCD(date='2015-11-07 00:00:00', Close='386.48199462890625')>,
#  < BTC_UCD(date='2015-11-08 00:00:00', Close='373.3680114746094')>,
#  < BTC_UCD(date='2015-11-09 00:00:00', Close='380.2569885253906')>,
#  < BTC_UCD(date='2015-11-10 00:00:00', Close='336.8190002441406')>,
#  < BTC_UCD(date='2015-11-11 00:00:00', Close='311.0840148925781')>,
#  < BTC_UCD(date='2015-11-12 00:00:00', Close='338.1520080566406')>,
#  < BTC_UCD(date='2015-11-13 00:00:00', Close='336.75299072265625')>,
#  < BTC_UCD(date='2015-11-14 00:00:00', Close='332.906005859375')>,
#  < BTC_UCD(date='2015-11-15 00:00:00', Close='320.1659851074219')>,
#  < BTC_UCD(date='2015-11-16 00:00:00', Close='330.7510070800781')>,
#  < BTC_UCD(date='2015-11-17 00:00:00', Close='335.093994140625')>,
#  < BTC_UCD(date='2015-11-18 00:00:00', Close='334.5899963378906')>,
#  < BTC_UCD(date='2015-11-19 00:00:00', Close='326.14898681640625')>,
#  < BTC_UCD(date='2015-11-20 00:00:00', Close='322.0220031738281')>,
#  < BTC_UCD(date='2015-11-21 00:00:00', Close='326.927001953125')>,
#  < BTC_UCD(date='2015-11-22 00:00:00', Close='324.5360107421875')>,
#  < BTC_UCD(date='2015-11-23 00:00:00', Close='323.0459899902344')>,
#  < BTC_UCD(date='2015-11-24 00:00:00', Close='320.0459899902344')>,
#  < BTC_UCD(date='2015-11-25 00:00:00', Close='328.20599365234375')>,
#  < BTC_UCD(date='2015-11-26 00:00:00', Close='352.6839904785156')>,
#  < BTC_UCD(date='2015-11-27 00:00:00', Close='358.0419921875')>,
#  < BTC_UCD(date='2015-11-28 00:00:00', Close='357.3810119628906')>,
#  < BTC_UCD(date='2015-11-29 00:00:00', Close='371.29400634765625')>,
#  < BTC_UCD(date='2015-11-30 00:00:00', Close='377.3210144042969')>,
#  < BTC_UCD(date='2015-12-01 00:00:00', Close='362.4880065917969')>,
#  < BTC_UCD(date='2015-12-02 00:00:00', Close='359.18701171875')>,
#  < BTC_UCD(date='2015-12-03 00:00:00', Close='361.0459899902344')>,
#  < BTC_UCD(date='2015-12-04 00:00:00', Close='363.1830139160156')>,
#  < BTC_UCD(date='2015-12-05 00:00:00', Close='388.9490051269531')>,
#  < BTC_UCD(date='2015-12-06 00:00:00', Close='388.7829895019531')>,
#  < BTC_UCD(date='2015-12-07 00:00:00', Close='395.5360107421875')>,
#  < BTC_UCD(date='2015-12-08 00:00:00', Close='415.56298828125')>,
#  < BTC_UCD(date='2015-12-09 00:00:00', Close='417.56298828125')>,
#  < BTC_UCD(date='2015-12-10 00:00:00', Close='415.47900390625')>,
#  < BTC_UCD(date='2015-12-11 00:00:00', Close='451.93798828125')>,
#  < BTC_UCD(date='2015-12-12 00:00:00', Close='434.99700927734375')>,
#  < BTC_UCD(date='2015-12-13 00:00:00', Close='433.7550048828125')>,
#  < BTC_UCD(date='2015-12-14 00:00:00', Close='444.1820068359375')>,
#  < BTC_UCD(date='2015-12-15 00:00:00', Close='465.3210144042969')>,
#  < BTC_UCD(date='2015-12-16 00:00:00', Close='454.9339904785156')>,
#  < BTC_UCD(date='2015-12-17 00:00:00', Close='456.0780029296875')>,
#  < BTC_UCD(date='2015-12-18 00:00:00', Close='463.6159973144531')>,
#  < BTC_UCD(date='2015-12-19 00:00:00', Close='462.3219909667969')>,
#  < BTC_UCD(date='2015-12-20 00:00:00', Close='442.68499755859375')>,
#  < BTC_UCD(date='2015-12-21 00:00:00', Close='438.6390075683594')>,
#  < BTC_UCD(date='2015-12-22 00:00:00', Close='436.5719909667969')>,
#  < BTC_UCD(date='2015-12-23 00:00:00', Close='442.4010009765625')>,
#  < BTC_UCD(date='2015-12-24 00:00:00', Close='454.9849853515625')>,
#  < BTC_UCD(date='2015-12-25 00:00:00', Close='455.65301513671875')>,
#  < BTC_UCD(date='2015-12-26 00:00:00', Close='417.27398681640625')>,
#  < BTC_UCD(date='2015-12-27 00:00:00', Close='422.822998046875')>,
#  < BTC_UCD(date='2015-12-28 00:00:00', Close='422.27899169921875')>,
#  < BTC_UCD(date='2015-12-29 00:00:00', Close='432.9830017089844')>,
#  < BTC_UCD(date='2015-12-30 00:00:00', Close='426.6199951171875')>,
#  < BTC_UCD(date='2015-12-31 00:00:00', Close='430.5669860839844')>,
#  < BTC_UCD(date='2016-01-01 00:00:00', Close='434.3340148925781')>,
#  < BTC_UCD(date='2016-01-02 00:00:00', Close='433.43798828125')>,
#  < BTC_UCD(date='2016-01-03 00:00:00', Close='430.010986328125')>,
#  < BTC_UCD(date='2016-01-04 00:00:00', Close='433.09100341796875')>,
#  < BTC_UCD(date='2016-01-05 00:00:00', Close='431.9599914550781')>,
#  < BTC_UCD(date='2016-01-06 00:00:00', Close='429.1050109863281')>,
#  < BTC_UCD(date='2016-01-07 00:00:00', Close='458.0480041503906')>,
#  < BTC_UCD(date='2016-01-08 00:00:00', Close='453.2300109863281')>,
#  < BTC_UCD(date='2016-01-09 00:00:00', Close='447.6109924316406')>,
#  < BTC_UCD(date='2016-01-10 00:00:00', Close='447.9909973144531')>,
#  < BTC_UCD(date='2016-01-11 00:00:00', Close='448.4280090332031')>,
#  < BTC_UCD(date='2016-01-12 00:00:00', Close='435.69000244140625')>,
#  < BTC_UCD(date='2016-01-13 00:00:00', Close='432.3710021972656')>,
#  < BTC_UCD(date='2016-01-14 00:00:00', Close='430.3059997558594')>,
#  < BTC_UCD(date='2016-01-15 00:00:00', Close='364.33099365234375')>,
#  < BTC_UCD(date='2016-01-16 00:00:00', Close='387.5360107421875')>,
#  < BTC_UCD(date='2016-01-17 00:00:00', Close='382.29901123046875')>,
#  < BTC_UCD(date='2016-01-18 00:00:00', Close='387.1679992675781')>,
#  < BTC_UCD(date='2016-01-19 00:00:00', Close='380.14898681640625')>,
#  < BTC_UCD(date='2016-01-20 00:00:00', Close='420.2300109863281')>,
#  < BTC_UCD(date='2016-01-21 00:00:00', Close='410.2619934082031')>,
#  < BTC_UCD(date='2016-01-22 00:00:00', Close='382.49200439453125')>,
#  < BTC_UCD(date='2016-01-23 00:00:00', Close='387.4909973144531')>,
#  < BTC_UCD(date='2016-01-24 00:00:00', Close='402.97100830078125')>,
#  < BTC_UCD(date='2016-01-25 00:00:00', Close='391.72601318359375')>,
#  < BTC_UCD(date='2016-01-26 00:00:00', Close='392.15301513671875')>,
#  < BTC_UCD(date='2016-01-27 00:00:00', Close='394.97198486328125')>,
#  < BTC_UCD(date='2016-01-28 00:00:00', Close='380.28900146484375')>,
#  < BTC_UCD(date='2016-01-29 00:00:00', Close='379.4739990234375')>,
#  < BTC_UCD(date='2016-01-30 00:00:00', Close='378.2550048828125')>,
#  < BTC_UCD(date='2016-01-31 00:00:00', Close='368.7669982910156')>,
#  < BTC_UCD(date='2016-02-01 00:00:00', Close='373.0559997558594')>,
#  < BTC_UCD(date='2016-02-02 00:00:00', Close='374.447998046875')>,
#  < BTC_UCD(date='2016-02-03 00:00:00', Close='369.9490051269531')>,
#  < BTC_UCD(date='2016-02-04 00:00:00', Close='389.593994140625')>,
#  < BTC_UCD(date='2016-02-05 00:00:00', Close='386.54901123046875')>,
#  < BTC_UCD(date='2016-02-06 00:00:00', Close='376.5220031738281')>,
#  < BTC_UCD(date='2016-02-07 00:00:00', Close='376.6199951171875')>,
#  < BTC_UCD(date='2016-02-08 00:00:00', Close='373.4469909667969')>,
#  < BTC_UCD(date='2016-02-09 00:00:00', Close='376.02899169921875')>,
#  < BTC_UCD(date='2016-02-10 00:00:00', Close='381.64898681640625')>,
#  < BTC_UCD(date='2016-02-11 00:00:00', Close='379.65399169921875')>,
#  < BTC_UCD(date='2016-02-12 00:00:00', Close='384.26300048828125')>,
#  < BTC_UCD(date='2016-02-13 00:00:00', Close='391.8599853515625')>,
#  < BTC_UCD(date='2016-02-14 00:00:00', Close='407.2300109863281')>,
#  < BTC_UCD(date='2016-02-15 00:00:00', Close='400.18499755859375')>,
#  < BTC_UCD(date='2016-02-16 00:00:00', Close='407.4880065917969')>,
#  < BTC_UCD(date='2016-02-17 00:00:00', Close='416.3219909667969')>,
#  < BTC_UCD(date='2016-02-18 00:00:00', Close='422.37298583984375')>,
#  < BTC_UCD(date='2016-02-19 00:00:00', Close='420.7850036621094')>,
#  < BTC_UCD(date='2016-02-20 00:00:00', Close='437.16400146484375')>,
#  < BTC_UCD(date='2016-02-21 00:00:00', Close='438.7980041503906')>,
#  < BTC_UCD(date='2016-02-22 00:00:00', Close='437.74798583984375')>,
#  < BTC_UCD(date='2016-02-23 00:00:00', Close='420.7359924316406')>,
#  < BTC_UCD(date='2016-02-24 00:00:00', Close='424.9549865722656')>,
#  < BTC_UCD(date='2016-02-25 00:00:00', Close='424.54400634765625')>,
#  < BTC_UCD(date='2016-02-26 00:00:00', Close='432.1520080566406')>,
#  < BTC_UCD(date='2016-02-27 00:00:00', Close='432.5190124511719')>,
#  < BTC_UCD(date='2016-02-28 00:00:00', Close='433.5039978027344')>,
#  < BTC_UCD(date='2016-02-29 00:00:00', Close='437.6969909667969')>,
#  < BTC_UCD(date='2016-03-01 00:00:00', Close='435.12298583984375')>,
#  < BTC_UCD(date='2016-03-02 00:00:00', Close='423.989013671875')>,
#  < BTC_UCD(date='2016-03-03 00:00:00', Close='421.6510009765625')>,
#  < BTC_UCD(date='2016-03-04 00:00:00', Close='410.9389953613281')>,
#  < BTC_UCD(date='2016-03-05 00:00:00', Close='400.57000732421875')>,
#  < BTC_UCD(date='2016-03-06 00:00:00', Close='407.7070007324219')>,
#  < BTC_UCD(date='2016-03-07 00:00:00', Close='414.3210144042969')>,
#  < BTC_UCD(date='2016-03-08 00:00:00', Close='413.97198486328125')>,
#  < BTC_UCD(date='2016-03-09 00:00:00', Close='414.8599853515625')>,
#  < BTC_UCD(date='2016-03-10 00:00:00', Close='417.1310119628906')>,
#  < BTC_UCD(date='2016-03-11 00:00:00', Close='421.69000244140625')>,
#  < BTC_UCD(date='2016-03-12 00:00:00', Close='411.6239929199219')>,
#  < BTC_UCD(date='2016-03-13 00:00:00', Close='414.06500244140625')>,
#  < BTC_UCD(date='2016-03-14 00:00:00', Close='416.43798828125')>,
#  < BTC_UCD(date='2016-03-15 00:00:00', Close='416.8299865722656')>,
#  < BTC_UCD(date='2016-03-16 00:00:00', Close='417.010986328125')>,
#  < BTC_UCD(date='2016-03-17 00:00:00', Close='420.6210021972656')>,
#  < BTC_UCD(date='2016-03-18 00:00:00', Close='409.5480041503906')>,
#  < BTC_UCD(date='2016-03-19 00:00:00', Close='410.4440002441406')>,
#  < BTC_UCD(date='2016-03-20 00:00:00', Close='413.7550048828125')>,
#  < BTC_UCD(date='2016-03-21 00:00:00', Close='413.3070068359375')>,
#  < BTC_UCD(date='2016-03-22 00:00:00', Close='418.0889892578125')>,
#  < BTC_UCD(date='2016-03-23 00:00:00', Close='418.0409851074219')>,
#  < BTC_UCD(date='2016-03-24 00:00:00', Close='416.3940124511719')>,
#  < BTC_UCD(date='2016-03-25 00:00:00', Close='417.177001953125')>,
#  < BTC_UCD(date='2016-03-26 00:00:00', Close='417.94500732421875')>,
#  < BTC_UCD(date='2016-03-27 00:00:00', Close='426.7650146484375')>,
#  < BTC_UCD(date='2016-03-28 00:00:00', Close='424.2309875488281')>,
#  < BTC_UCD(date='2016-03-29 00:00:00', Close='416.5159912109375')>,
#  < BTC_UCD(date='2016-03-30 00:00:00', Close='414.8160095214844')>,
#  < BTC_UCD(date='2016-03-31 00:00:00', Close='416.72900390625')>,
#  < BTC_UCD(date='2016-04-01 00:00:00', Close='417.9599914550781')>,
#  < BTC_UCD(date='2016-04-02 00:00:00', Close='420.87298583984375')>,
#  < BTC_UCD(date='2016-04-03 00:00:00', Close='420.90399169921875')>,
#  < BTC_UCD(date='2016-04-04 00:00:00', Close='421.4440002441406')>,
#  < BTC_UCD(date='2016-04-05 00:00:00', Close='424.0299987792969')>,
#  < BTC_UCD(date='2016-04-06 00:00:00', Close='423.4129943847656')>,
#  < BTC_UCD(date='2016-04-07 00:00:00', Close='422.7449951171875')>,
#  < BTC_UCD(date='2016-04-08 00:00:00', Close='420.3489990234375')>,
#  < BTC_UCD(date='2016-04-09 00:00:00', Close='419.4110107421875')>,
#  < BTC_UCD(date='2016-04-10 00:00:00', Close='421.5639953613281')>,
#  < BTC_UCD(date='2016-04-11 00:00:00', Close='422.4830017089844')>,
#  < BTC_UCD(date='2016-04-12 00:00:00', Close='425.19000244140625')>,
#  < BTC_UCD(date='2016-04-13 00:00:00', Close='423.7340087890625')>,
#  < BTC_UCD(date='2016-04-14 00:00:00', Close='424.2820129394531')>,
#  < BTC_UCD(date='2016-04-15 00:00:00', Close='429.7130126953125')>,
#  < BTC_UCD(date='2016-04-16 00:00:00', Close='430.5719909667969')>,
#  < BTC_UCD(date='2016-04-17 00:00:00', Close='427.39898681640625')>,
#  < BTC_UCD(date='2016-04-18 00:00:00', Close='428.59100341796875')>,
#  < BTC_UCD(date='2016-04-19 00:00:00', Close='435.5090026855469')>,
#  < BTC_UCD(date='2016-04-20 00:00:00', Close='441.3890075683594')>,
#  < BTC_UCD(date='2016-04-21 00:00:00', Close='449.42498779296875')>,
#  < BTC_UCD(date='2016-04-22 00:00:00', Close='445.73699951171875')>,
#  < BTC_UCD(date='2016-04-23 00:00:00', Close='450.2820129394531')>,
#  < BTC_UCD(date='2016-04-24 00:00:00', Close='458.55499267578125')>,
#  < BTC_UCD(date='2016-04-25 00:00:00', Close='461.4259948730469')>,
#  < BTC_UCD(date='2016-04-26 00:00:00', Close='466.0889892578125')>,
#  < BTC_UCD(date='2016-04-27 00:00:00', Close='444.68701171875')>,
#  < BTC_UCD(date='2016-04-28 00:00:00', Close='449.010986328125')>,
#  < BTC_UCD(date='2016-04-29 00:00:00', Close='455.09698486328125')>,
#  < BTC_UCD(date='2016-04-30 00:00:00', Close='448.3179931640625')>,
#  < BTC_UCD(date='2016-05-01 00:00:00', Close='451.875')>,
#  < BTC_UCD(date='2016-05-02 00:00:00', Close='444.66900634765625')>,
#  < BTC_UCD(date='2016-05-03 00:00:00', Close='450.3039855957031')>,
#  < BTC_UCD(date='2016-05-04 00:00:00', Close='446.72198486328125')>,
#  < BTC_UCD(date='2016-05-05 00:00:00', Close='447.97601318359375')>,
#  < BTC_UCD(date='2016-05-06 00:00:00', Close='459.6029968261719')>,
#  < BTC_UCD(date='2016-05-07 00:00:00', Close='458.5360107421875')>,
#  < BTC_UCD(date='2016-05-08 00:00:00', Close='458.5480041503906')>,
#  < BTC_UCD(date='2016-05-09 00:00:00', Close='460.4830017089844')>,
#  < BTC_UCD(date='2016-05-10 00:00:00', Close='450.8949890136719')>,
#  < BTC_UCD(date='2016-05-11 00:00:00', Close='452.7279968261719')>,
#  < BTC_UCD(date='2016-05-12 00:00:00', Close='454.7659912109375')>,
#  < BTC_UCD(date='2016-05-13 00:00:00', Close='455.6700134277344')>,
#  < BTC_UCD(date='2016-05-14 00:00:00', Close='455.6709899902344')>,
#  < BTC_UCD(date='2016-05-15 00:00:00', Close='457.5679931640625')>,
#  < BTC_UCD(date='2016-05-16 00:00:00', Close='454.1629943847656')>,
#  < BTC_UCD(date='2016-05-17 00:00:00', Close='453.7829895019531')>,
#  < BTC_UCD(date='2016-05-18 00:00:00', Close='454.6189880371094')>,
#  < BTC_UCD(date='2016-05-19 00:00:00', Close='438.7149963378906')>,
#  < BTC_UCD(date='2016-05-20 00:00:00', Close='442.6759948730469')>,
#  < BTC_UCD(date='2016-05-21 00:00:00', Close='443.18798828125')>,
#  < BTC_UCD(date='2016-05-22 00:00:00', Close='439.322998046875')>,
#  < BTC_UCD(date='2016-05-23 00:00:00', Close='444.1549987792969')>,
#  < BTC_UCD(date='2016-05-24 00:00:00', Close='445.9809875488281')>,
#  < BTC_UCD(date='2016-05-25 00:00:00', Close='449.5989990234375')>,
#  < BTC_UCD(date='2016-05-26 00:00:00', Close='453.3840026855469')>,
#  < BTC_UCD(date='2016-05-27 00:00:00', Close='473.4639892578125')>,
#  < BTC_UCD(date='2016-05-28 00:00:00', Close='530.0399780273438')>,
#  < BTC_UCD(date='2016-05-29 00:00:00', Close='526.2329711914062')>,
#  < BTC_UCD(date='2016-05-30 00:00:00', Close='533.864013671875')>,
#  < BTC_UCD(date='2016-05-31 00:00:00', Close='531.385986328125')>,
#  < BTC_UCD(date='2016-06-01 00:00:00', Close='536.9199829101562')>,
#  < BTC_UCD(date='2016-06-02 00:00:00', Close='537.9719848632812')>,
#  < BTC_UCD(date='2016-06-03 00:00:00', Close='569.1939697265625')>,
#  < BTC_UCD(date='2016-06-04 00:00:00', Close='572.7269897460938')>,
#  < BTC_UCD(date='2016-06-05 00:00:00', Close='574.9769897460938')>,
#  < BTC_UCD(date='2016-06-06 00:00:00', Close='585.5369873046875')>,
#  < BTC_UCD(date='2016-06-07 00:00:00', Close='576.5969848632812')>,
#  < BTC_UCD(date='2016-06-08 00:00:00', Close='581.64501953125')>,
#  < BTC_UCD(date='2016-06-09 00:00:00', Close='574.6300048828125')>,
#  < BTC_UCD(date='2016-06-10 00:00:00', Close='577.469970703125')>,
#  < BTC_UCD(date='2016-06-11 00:00:00', Close='606.7269897460938')>,
#  < BTC_UCD(date='2016-06-12 00:00:00', Close='672.7839965820312')>,
#  < BTC_UCD(date='2016-06-13 00:00:00', Close='704.3759765625')>,
#  < BTC_UCD(date='2016-06-14 00:00:00', Close='685.5590209960938')>,
#  < BTC_UCD(date='2016-06-15 00:00:00', Close='694.468994140625')>,
#  < BTC_UCD(date='2016-06-16 00:00:00', Close='766.3079833984375')>,
#  < BTC_UCD(date='2016-06-17 00:00:00', Close='748.9089965820312')>,
#  < BTC_UCD(date='2016-06-18 00:00:00', Close='756.2269897460938')>,
#  < BTC_UCD(date='2016-06-19 00:00:00', Close='763.781005859375')>,
#  < BTC_UCD(date='2016-06-20 00:00:00', Close='737.2260131835938')>,
#  < BTC_UCD(date='2016-06-21 00:00:00', Close='666.6519775390625')>,
#  < BTC_UCD(date='2016-06-22 00:00:00', Close='596.1160278320312')>,
#  < BTC_UCD(date='2016-06-23 00:00:00', Close='623.9769897460938')>,
#  < BTC_UCD(date='2016-06-24 00:00:00', Close='665.2990112304688')>,
#  < BTC_UCD(date='2016-06-25 00:00:00', Close='665.1229858398438')>,
#  < BTC_UCD(date='2016-06-26 00:00:00', Close='629.3670043945312')>,
#  < BTC_UCD(date='2016-06-27 00:00:00', Close='655.2750244140625')>,
#  < BTC_UCD(date='2016-06-28 00:00:00', Close='647.0009765625')>,
#  < BTC_UCD(date='2016-06-29 00:00:00', Close='639.8900146484375')>,
#  < BTC_UCD(date='2016-06-30 00:00:00', Close='673.3369750976562')>,
#  < BTC_UCD(date='2016-07-01 00:00:00', Close='676.2960205078125')>,
#  < BTC_UCD(date='2016-07-02 00:00:00', Close='703.7020263671875')>,
#  < BTC_UCD(date='2016-07-03 00:00:00', Close='658.6640014648438')>,
#  < BTC_UCD(date='2016-07-04 00:00:00', Close='683.6619873046875')>,
#  < BTC_UCD(date='2016-07-05 00:00:00', Close='670.6270141601562')>,
#  < BTC_UCD(date='2016-07-06 00:00:00', Close='677.3309936523438')>,
#  < BTC_UCD(date='2016-07-07 00:00:00', Close='640.56201171875')>,
#  < BTC_UCD(date='2016-07-08 00:00:00', Close='666.5230102539062')>,
#  < BTC_UCD(date='2016-07-09 00:00:00', Close='650.9600219726562')>,
#  < BTC_UCD(date='2016-07-10 00:00:00', Close='649.3599853515625')>,
#  < BTC_UCD(date='2016-07-11 00:00:00', Close='647.6589965820312')>,
#  < BTC_UCD(date='2016-07-12 00:00:00', Close='664.551025390625')>,
#  < BTC_UCD(date='2016-07-13 00:00:00', Close='654.468017578125')>,
#  < BTC_UCD(date='2016-07-14 00:00:00', Close='658.0780029296875')>,
#  < BTC_UCD(date='2016-07-15 00:00:00', Close='663.2550048828125')>,
#  < BTC_UCD(date='2016-07-16 00:00:00', Close='660.7670288085938')>,
#  < BTC_UCD(date='2016-07-17 00:00:00', Close='679.458984375')>,
#  < BTC_UCD(date='2016-07-18 00:00:00', Close='673.1060180664062')>,
#  < BTC_UCD(date='2016-07-19 00:00:00', Close='672.864013671875')>,
#  < BTC_UCD(date='2016-07-20 00:00:00', Close='665.6849975585938')>,
#  < BTC_UCD(date='2016-07-21 00:00:00', Close='665.0120239257812')>,
#  < BTC_UCD(date='2016-07-22 00:00:00', Close='650.6190185546875')>,
#  < BTC_UCD(date='2016-07-23 00:00:00', Close='655.5560302734375')>,
#  < BTC_UCD(date='2016-07-24 00:00:00', Close='661.2849731445312')>,
#  < BTC_UCD(date='2016-07-25 00:00:00', Close='654.0969848632812')>,
#  < BTC_UCD(date='2016-07-26 00:00:00', Close='651.7839965820312')>,
#  < BTC_UCD(date='2016-07-27 00:00:00', Close='654.3519897460938')>,
#  < BTC_UCD(date='2016-07-28 00:00:00', Close='655.0349731445312')>,
#  < BTC_UCD(date='2016-07-29 00:00:00', Close='656.9920043945312')>,
#  < BTC_UCD(date='2016-07-30 00:00:00', Close='655.0469970703125')>,
#  < BTC_UCD(date='2016-07-31 00:00:00', Close='624.6810302734375')>,
#  < BTC_UCD(date='2016-08-01 00:00:00', Close='606.27197265625')>,
#  < BTC_UCD(date='2016-08-02 00:00:00', Close='547.4650268554688')>,
#  < BTC_UCD(date='2016-08-03 00:00:00', Close='566.35498046875')>,
#  < BTC_UCD(date='2016-08-04 00:00:00', Close='578.2890014648438')>,
#  < BTC_UCD(date='2016-08-05 00:00:00', Close='575.0430297851562')>,
#  < BTC_UCD(date='2016-08-06 00:00:00', Close='587.7780151367188')>,
#  < BTC_UCD(date='2016-08-07 00:00:00', Close='592.6900024414062')>,
#  < BTC_UCD(date='2016-08-08 00:00:00', Close='591.0540161132812')>,
#  < BTC_UCD(date='2016-08-09 00:00:00', Close='587.801025390625')>,
#  < BTC_UCD(date='2016-08-10 00:00:00', Close='592.10302734375')>,
#  < BTC_UCD(date='2016-08-11 00:00:00', Close='589.1199951171875')>,
#  < BTC_UCD(date='2016-08-12 00:00:00', Close='587.5590209960938')>,
#  < BTC_UCD(date='2016-08-13 00:00:00', Close='585.5880126953125')>,
#  < BTC_UCD(date='2016-08-14 00:00:00', Close='570.4730224609375')>,
#  < BTC_UCD(date='2016-08-15 00:00:00', Close='567.239990234375')>,
#  < BTC_UCD(date='2016-08-16 00:00:00', Close='577.4390258789062')>,
#  < BTC_UCD(date='2016-08-17 00:00:00', Close='573.2160034179688')>,
#  < BTC_UCD(date='2016-08-18 00:00:00', Close='574.3179931640625')>,
#  < BTC_UCD(date='2016-08-19 00:00:00', Close='575.6300048828125')>,
#  < BTC_UCD(date='2016-08-20 00:00:00', Close='581.697021484375')>,
#  < BTC_UCD(date='2016-08-21 00:00:00', Close='581.3079833984375')>,
#  < BTC_UCD(date='2016-08-22 00:00:00', Close='586.7529907226562')>,
#  < BTC_UCD(date='2016-08-23 00:00:00', Close='583.4149780273438')>,
#  < BTC_UCD(date='2016-08-24 00:00:00', Close='580.1820068359375')>,
#  < BTC_UCD(date='2016-08-25 00:00:00', Close='577.760986328125')>,
#  < BTC_UCD(date='2016-08-26 00:00:00', Close='579.6510009765625')>,
#  < BTC_UCD(date='2016-08-27 00:00:00', Close='569.947021484375')>,
#  < BTC_UCD(date='2016-08-28 00:00:00', Close='573.9119873046875')>,
#  < BTC_UCD(date='2016-08-29 00:00:00', Close='574.1069946289062')>,
#  < BTC_UCD(date='2016-08-30 00:00:00', Close='577.5029907226562')>,
#  < BTC_UCD(date='2016-08-31 00:00:00', Close='575.4719848632812')>,
#  < BTC_UCD(date='2016-09-01 00:00:00', Close='572.302978515625')>,
#  < BTC_UCD(date='2016-09-02 00:00:00', Close='575.5369873046875')>,
#  < BTC_UCD(date='2016-09-03 00:00:00', Close='598.2119750976562')>,
#  < BTC_UCD(date='2016-09-04 00:00:00', Close='608.6339721679688')>,
#  < BTC_UCD(date='2016-09-05 00:00:00', Close='606.5900268554688')>,
#  < BTC_UCD(date='2016-09-06 00:00:00', Close='610.4359741210938')>,
#  < BTC_UCD(date='2016-09-07 00:00:00', Close='614.5440063476562')>,
#  < BTC_UCD(date='2016-09-08 00:00:00', Close='626.3159790039062')>,
#  < BTC_UCD(date='2016-09-09 00:00:00', Close='622.8610229492188')>,
#  < BTC_UCD(date='2016-09-10 00:00:00', Close='623.5089721679688')>,
#  < BTC_UCD(date='2016-09-11 00:00:00', Close='606.718994140625')>,
#  < BTC_UCD(date='2016-09-12 00:00:00', Close='608.2429809570312')>,
#  < BTC_UCD(date='2016-09-13 00:00:00', Close='609.2410278320312')>,
#  < BTC_UCD(date='2016-09-14 00:00:00', Close='610.6840209960938')>,
#  < BTC_UCD(date='2016-09-15 00:00:00', Close='607.155029296875')>,
#  < BTC_UCD(date='2016-09-16 00:00:00', Close='606.9730224609375')>,
#  < BTC_UCD(date='2016-09-17 00:00:00', Close='605.9840087890625')>,
#  < BTC_UCD(date='2016-09-18 00:00:00', Close='609.8740234375')>,
#  < BTC_UCD(date='2016-09-19 00:00:00', Close='609.2269897460938')>,
#  < BTC_UCD(date='2016-09-20 00:00:00', Close='608.31201171875')>,
#  < BTC_UCD(date='2016-09-21 00:00:00', Close='597.1489868164062')>,
#  < BTC_UCD(date='2016-09-22 00:00:00', Close='596.2979736328125')>,
#  < BTC_UCD(date='2016-09-23 00:00:00', Close='602.8419799804688')>,
#  < BTC_UCD(date='2016-09-24 00:00:00', Close='602.625')>,
#  < BTC_UCD(date='2016-09-25 00:00:00', Close='600.8259887695312')>,
#  < BTC_UCD(date='2016-09-26 00:00:00', Close='608.0430297851562')>,
#  < BTC_UCD(date='2016-09-27 00:00:00', Close='606.166015625')>,
#  < BTC_UCD(date='2016-09-28 00:00:00', Close='604.72802734375')>,
#  < BTC_UCD(date='2016-09-29 00:00:00', Close='605.6929931640625')>,
#  < BTC_UCD(date='2016-09-30 00:00:00', Close='609.7349853515625')>,
#  < BTC_UCD(date='2016-10-01 00:00:00', Close='613.9829711914062')>,
#  < BTC_UCD(date='2016-10-02 00:00:00', Close='610.8920288085938')>,
#  < BTC_UCD(date='2016-10-03 00:00:00', Close='612.1329956054688')>,
#  < BTC_UCD(date='2016-10-04 00:00:00', Close='610.2039794921875')>,
#  < BTC_UCD(date='2016-10-05 00:00:00', Close='612.510986328125')>,
#  < BTC_UCD(date='2016-10-06 00:00:00', Close='613.02099609375')>,
#  < BTC_UCD(date='2016-10-07 00:00:00', Close='617.1209716796875')>,
#  < BTC_UCD(date='2016-10-08 00:00:00', Close='619.1079711914062')>,
#  < BTC_UCD(date='2016-10-09 00:00:00', Close='616.7520141601562')>,
#  < BTC_UCD(date='2016-10-10 00:00:00', Close='618.9940185546875')>,
#  < BTC_UCD(date='2016-10-11 00:00:00', Close='641.072021484375')>,
#  < BTC_UCD(date='2016-10-12 00:00:00', Close='636.1920166015625')>,
#  < BTC_UCD(date='2016-10-13 00:00:00', Close='636.7860107421875')>,
#  < BTC_UCD(date='2016-10-14 00:00:00', Close='640.3779907226562')>,
#  < BTC_UCD(date='2016-10-15 00:00:00', Close='638.64599609375')>,
#  < BTC_UCD(date='2016-10-16 00:00:00', Close='641.6309814453125')>,
#  < BTC_UCD(date='2016-10-17 00:00:00', Close='639.1929931640625')>,
#  < BTC_UCD(date='2016-10-18 00:00:00', Close='637.9600219726562')>,
#  < BTC_UCD(date='2016-10-19 00:00:00', Close='630.52001953125')>,
#  < BTC_UCD(date='2016-10-20 00:00:00', Close='630.8569946289062')>,
#  < BTC_UCD(date='2016-10-21 00:00:00', Close='632.8280029296875')>,
#  < BTC_UCD(date='2016-10-22 00:00:00', Close='657.2940063476562')>,
#  < BTC_UCD(date='2016-10-23 00:00:00', Close='657.0709838867188')>,
#  < BTC_UCD(date='2016-10-24 00:00:00', Close='653.760986328125')>,
#  < BTC_UCD(date='2016-10-25 00:00:00', Close='657.5880126953125')>,
#  < BTC_UCD(date='2016-10-26 00:00:00', Close='678.3040161132812')>,
#  < BTC_UCD(date='2016-10-27 00:00:00', Close='688.31298828125')>,
#  < BTC_UCD(date='2016-10-28 00:00:00', Close='689.6510009765625')>,
#  < BTC_UCD(date='2016-10-29 00:00:00', Close='714.47900390625')>,
#  < BTC_UCD(date='2016-10-30 00:00:00', Close='701.864013671875')>,
#  < BTC_UCD(date='2016-10-31 00:00:00', Close='700.9719848632812')>,
#  < BTC_UCD(date='2016-11-01 00:00:00', Close='729.7930297851562')>,
#  < BTC_UCD(date='2016-11-02 00:00:00', Close='740.8289794921875')>,
#  < BTC_UCD(date='2016-11-03 00:00:00', Close='688.7000122070312')>,
#  < BTC_UCD(date='2016-11-04 00:00:00', Close='703.2349853515625')>,
#  < BTC_UCD(date='2016-11-05 00:00:00', Close='703.4180297851562')>,
#  < BTC_UCD(date='2016-11-06 00:00:00', Close='711.52197265625')>,
#  < BTC_UCD(date='2016-11-07 00:00:00', Close='703.1309814453125')>,
#  < BTC_UCD(date='2016-11-08 00:00:00', Close='709.8480224609375')>,
#  < BTC_UCD(date='2016-11-09 00:00:00', Close='723.2730102539062')>,
#  < BTC_UCD(date='2016-11-10 00:00:00', Close='715.5339965820312')>,
#  < BTC_UCD(date='2016-11-11 00:00:00', Close='716.4110107421875')>,
#  < BTC_UCD(date='2016-11-12 00:00:00', Close='705.0540161132812')>,
#  < BTC_UCD(date='2016-11-13 00:00:00', Close='702.031005859375')>,
#  < BTC_UCD(date='2016-11-14 00:00:00', Close='705.02099609375')>,
#  < BTC_UCD(date='2016-11-15 00:00:00', Close='711.6190185546875')>,
#  < BTC_UCD(date='2016-11-16 00:00:00', Close='744.197998046875')>,
#  < BTC_UCD(date='2016-11-17 00:00:00', Close='740.9769897460938')>,
#  < BTC_UCD(date='2016-11-18 00:00:00', Close='751.5850219726562')>,
#  < BTC_UCD(date='2016-11-19 00:00:00', Close='751.6160278320312')>,
#  < BTC_UCD(date='2016-11-20 00:00:00', Close='731.0260009765625')>,
#  < BTC_UCD(date='2016-11-21 00:00:00', Close='739.2479858398438')>,
#  < BTC_UCD(date='2016-11-22 00:00:00', Close='751.3469848632812')>,
#  < BTC_UCD(date='2016-11-23 00:00:00', Close='744.593994140625')>,
#  < BTC_UCD(date='2016-11-24 00:00:00', Close='740.2890014648438')>,
#  < BTC_UCD(date='2016-11-25 00:00:00', Close='741.6489868164062')>,
#  < BTC_UCD(date='2016-11-26 00:00:00', Close='735.3820190429688')>,
#  < BTC_UCD(date='2016-11-27 00:00:00', Close='732.0349731445312')>,
#  < BTC_UCD(date='2016-11-28 00:00:00', Close='735.81298828125')>,
#  < BTC_UCD(date='2016-11-29 00:00:00', Close='735.60400390625')>,
#  < BTC_UCD(date='2016-11-30 00:00:00', Close='745.6909790039062')>,
#  < BTC_UCD(date='2016-12-01 00:00:00', Close='756.7739868164062')>,
#  < BTC_UCD(date='2016-12-02 00:00:00', Close='777.9439697265625')>,
#  < BTC_UCD(date='2016-12-03 00:00:00', Close='771.155029296875')>,
#  < BTC_UCD(date='2016-12-04 00:00:00', Close='773.8720092773438')>,
#  < BTC_UCD(date='2016-12-05 00:00:00', Close='758.7000122070312')>,
# ...
#  < BTC_UCD(date='2017-02-02 00:00:00', Close='1011.7999877929688')>,
#  < BTC_UCD(date='2017-02-03 00:00:00', Close='1029.9100341796875')>,
#  < BTC_UCD(date='2017-02-04 00:00:00', Close='1042.9000244140625')>,
#  < BTC_UCD(date='2017-02-05 00:00:00', Close='1027.3399658203125')>,
#  < BTC_UCD(date='2017-02-06 00:00:00', Close='1038.1500244140625')>,
#  < BTC_UCD(date='2017-02-07 00:00:00', Close='1061.3499755859375')>,
#  < BTC_UCD(date='2017-02-08 00:00:00', Close='1063.0699462890625')>,
#  < BTC_UCD(date='2017-02-09 00:00:00', Close='994.3829956054688')>,
#  < BTC_UCD(date='2017-02-10 00:00:00', Close='988.6740112304688')>,
#  < BTC_UCD(date='2017-02-11 00:00:00', Close='1004.4500122070312')>,
#  < BTC_UCD(date='2017-02-12 00:00:00', Close='999.1810302734375')>,
#  < BTC_UCD(date='2017-02-13 00:00:00', Close='990.6420288085938')>,
#  < BTC_UCD(date='2017-02-14 00:00:00', Close='1004.5499877929688')>,
#  < BTC_UCD(date='2017-02-15 00:00:00', Close='1007.47998046875')>,
#  < BTC_UCD(date='2017-02-16 00:00:00', Close='1027.43994140625')>,
#  < BTC_UCD(date='2017-02-17 00:00:00', Close='1046.2099609375')>,
#  < BTC_UCD(date='2017-02-18 00:00:00', Close='1054.4200439453125')>,
#  < BTC_UCD(date='2017-02-19 00:00:00', Close='1047.8699951171875')>,
#  < BTC_UCD(date='2017-02-20 00:00:00', Close='1079.97998046875')>,
#  < BTC_UCD(date='2017-02-21 00:00:00', Close='1115.300048828125')>,
#  < BTC_UCD(date='2017-02-22 00:00:00', Close='1117.43994140625')>,
#  < BTC_UCD(date='2017-02-23 00:00:00', Close='1166.719970703125')>,
#  < BTC_UCD(date='2017-02-24 00:00:00', Close='1173.6800537109375')>,
#  < BTC_UCD(date='2017-02-25 00:00:00', Close='1143.8399658203125')>,
#  < BTC_UCD(date='2017-02-26 00:00:00', Close='1165.199951171875')>,
#  < BTC_UCD(date='2017-02-27 00:00:00', Close='1179.969970703125')>,
#  < BTC_UCD(date='2017-02-28 00:00:00', Close='1179.969970703125')>,
#  < BTC_UCD(date='2017-03-01 00:00:00', Close='1222.5')>,
#  < BTC_UCD(date='2017-03-02 00:00:00', Close='1251.010009765625')>,
#  < BTC_UCD(date='2017-03-03 00:00:00', Close='1274.989990234375')>,
#  < BTC_UCD(date='2017-03-04 00:00:00', Close='1255.1500244140625')>,
#  < BTC_UCD(date='2017-03-05 00:00:00', Close='1267.1199951171875')>,
#  < BTC_UCD(date='2017-03-06 00:00:00', Close='1272.8299560546875')>,
#  < BTC_UCD(date='2017-03-07 00:00:00', Close='1223.5400390625')>,
#  < BTC_UCD(date='2017-03-08 00:00:00', Close='1150.0')>,
#  < BTC_UCD(date='2017-03-09 00:00:00', Close='1188.489990234375')>,
#  < BTC_UCD(date='2017-03-10 00:00:00', Close='1116.719970703125')>,
#  < BTC_UCD(date='2017-03-11 00:00:00', Close='1175.8299560546875')>,
#  < BTC_UCD(date='2017-03-12 00:00:00', Close='1221.3800048828125')>,
#  < BTC_UCD(date='2017-03-13 00:00:00', Close='1231.9200439453125')>,
#  < BTC_UCD(date='2017-03-14 00:00:00', Close='1240.0')>,
#  < BTC_UCD(date='2017-03-15 00:00:00', Close='1249.6099853515625')>,
#  < BTC_UCD(date='2017-03-16 00:00:00', Close='1187.81005859375')>,
#  < BTC_UCD(date='2017-03-17 00:00:00', Close='1100.22998046875')>,
#  < BTC_UCD(date='2017-03-18 00:00:00', Close='973.8179931640625')>,
#  < BTC_UCD(date='2017-03-19 00:00:00', Close='1036.739990234375')>,
#  < BTC_UCD(date='2017-03-20 00:00:00', Close='1054.22998046875')>,
#  < BTC_UCD(date='2017-03-21 00:00:00', Close='1120.5400390625')>,
#  < BTC_UCD(date='2017-03-22 00:00:00', Close='1049.1400146484375')>,
#  < BTC_UCD(date='2017-03-23 00:00:00', Close='1038.5899658203125')>,
#  < BTC_UCD(date='2017-03-24 00:00:00', Close='937.52001953125')>,
#  < BTC_UCD(date='2017-03-25 00:00:00', Close='972.7789916992188')>,
#  < BTC_UCD(date='2017-03-26 00:00:00', Close='966.7249755859375')>,
#  < BTC_UCD(date='2017-03-27 00:00:00', Close='1045.77001953125')>,
#  < BTC_UCD(date='2017-03-28 00:00:00', Close='1047.1500244140625')>,
#  < BTC_UCD(date='2017-03-29 00:00:00', Close='1039.969970703125')>,
#  < BTC_UCD(date='2017-03-30 00:00:00', Close='1026.4300537109375')>,
#  < BTC_UCD(date='2017-03-31 00:00:00', Close='1071.7900390625')>,
#  < BTC_UCD(date='2017-04-01 00:00:00', Close='1080.5')>,
#  < BTC_UCD(date='2017-04-02 00:00:00', Close='1102.1700439453125')>,
#  < BTC_UCD(date='2017-04-03 00:00:00', Close='1143.81005859375')>,
#  < BTC_UCD(date='2017-04-04 00:00:00', Close='1133.25')>,
#  < BTC_UCD(date='2017-04-05 00:00:00', Close='1124.780029296875')>,
#  < BTC_UCD(date='2017-04-06 00:00:00', Close='1182.6800537109375')>,
#  < BTC_UCD(date='2017-04-07 00:00:00', Close='1176.9000244140625')>,
#  < BTC_UCD(date='2017-04-08 00:00:00', Close='1175.949951171875')>,
#  < BTC_UCD(date='2017-04-09 00:00:00', Close='1187.8699951171875')>,
#  < BTC_UCD(date='2017-04-10 00:00:00', Close='1187.1300048828125')>,
#  < BTC_UCD(date='2017-04-11 00:00:00', Close='1205.010009765625')>,
#  < BTC_UCD(date='2017-04-12 00:00:00', Close='1200.3699951171875')>,
#  < BTC_UCD(date='2017-04-13 00:00:00', Close='1169.280029296875')>,
#  < BTC_UCD(date='2017-04-14 00:00:00', Close='1167.5400390625')>,
#  < BTC_UCD(date='2017-04-15 00:00:00', Close='1172.52001953125')>,
#  < BTC_UCD(date='2017-04-16 00:00:00', Close='1182.93994140625')>,
#  < BTC_UCD(date='2017-04-17 00:00:00', Close='1193.9100341796875')>,
#  < BTC_UCD(date='2017-04-18 00:00:00', Close='1211.6700439453125')>,
#  < BTC_UCD(date='2017-04-19 00:00:00', Close='1210.2900390625')>,
#  < BTC_UCD(date='2017-04-20 00:00:00', Close='1229.0799560546875')>,
#  < BTC_UCD(date='2017-04-21 00:00:00', Close='1222.050048828125')>,
#  < BTC_UCD(date='2017-04-22 00:00:00', Close='1231.7099609375')>,
#  < BTC_UCD(date='2017-04-23 00:00:00', Close='1207.2099609375')>,
#  < BTC_UCD(date='2017-04-24 00:00:00', Close='1250.1500244140625')>,
#  < BTC_UCD(date='2017-04-25 00:00:00', Close='1265.489990234375')>,
#  < BTC_UCD(date='2017-04-26 00:00:00', Close='1281.0799560546875')>,
#  < BTC_UCD(date='2017-04-27 00:00:00', Close='1317.72998046875')>,
#  < BTC_UCD(date='2017-04-28 00:00:00', Close='1316.47998046875')>,
#  < BTC_UCD(date='2017-04-29 00:00:00', Close='1321.7900390625')>,
#  < BTC_UCD(date='2017-04-30 00:00:00', Close='1347.8900146484375')>,
#  < BTC_UCD(date='2017-05-01 00:00:00', Close='1421.5999755859375')>,
#  < BTC_UCD(date='2017-05-02 00:00:00', Close='1452.8199462890625')>,
#  < BTC_UCD(date='2017-05-03 00:00:00', Close='1490.0899658203125')>,
#  < BTC_UCD(date='2017-05-04 00:00:00', Close='1537.6700439453125')>,
#  < BTC_UCD(date='2017-05-05 00:00:00', Close='1555.449951171875')>,
#  < BTC_UCD(date='2017-05-06 00:00:00', Close='1578.800048828125')>,
#  < BTC_UCD(date='2017-05-07 00:00:00', Close='1596.7099609375')>,
#  < BTC_UCD(date='2017-05-08 00:00:00', Close='1723.3499755859375')>,
#  < BTC_UCD(date='2017-05-09 00:00:00', Close='1755.3599853515625')>,
#  < BTC_UCD(date='2017-05-10 00:00:00', Close='1787.1300048828125')>,
#  < BTC_UCD(date='2017-05-11 00:00:00', Close='1848.5699462890625')>,
#  < BTC_UCD(date='2017-05-12 00:00:00', Close='1724.239990234375')>,
#  < BTC_UCD(date='2017-05-13 00:00:00', Close='1804.9100341796875')>,
#  < BTC_UCD(date='2017-05-14 00:00:00', Close='1808.9100341796875')>,
#  < BTC_UCD(date='2017-05-15 00:00:00', Close='1738.4300537109375')>,
#  < BTC_UCD(date='2017-05-16 00:00:00', Close='1734.449951171875')>,
#  < BTC_UCD(date='2017-05-17 00:00:00', Close='1839.0899658203125')>,
#  < BTC_UCD(date='2017-05-18 00:00:00', Close='1888.6500244140625')>,
#  < BTC_UCD(date='2017-05-19 00:00:00', Close='1987.7099609375')>,
#  < BTC_UCD(date='2017-05-20 00:00:00', Close='2084.72998046875')>,
#  < BTC_UCD(date='2017-05-21 00:00:00', Close='2041.199951171875')>,
#  < BTC_UCD(date='2017-05-22 00:00:00', Close='2173.39990234375')>,
#  < BTC_UCD(date='2017-05-23 00:00:00', Close='2320.419921875')>,
#  < BTC_UCD(date='2017-05-24 00:00:00', Close='2443.639892578125')>,
#  < BTC_UCD(date='2017-05-25 00:00:00', Close='2304.97998046875')>,
#  < BTC_UCD(date='2017-05-26 00:00:00', Close='2202.419921875')>,
#  < BTC_UCD(date='2017-05-27 00:00:00', Close='2038.8699951171875')>,
#  < BTC_UCD(date='2017-05-28 00:00:00', Close='2155.800048828125')>,
#  < BTC_UCD(date='2017-05-29 00:00:00', Close='2255.610107421875')>,
#  < BTC_UCD(date='2017-05-30 00:00:00', Close='2175.469970703125')>,
#  < BTC_UCD(date='2017-05-31 00:00:00', Close='2286.409912109375')>,
#  < BTC_UCD(date='2017-06-01 00:00:00', Close='2407.8798828125')>,
#  < BTC_UCD(date='2017-06-02 00:00:00', Close='2488.550048828125')>,
#  < BTC_UCD(date='2017-06-03 00:00:00', Close='2515.35009765625')>,
#  < BTC_UCD(date='2017-06-04 00:00:00', Close='2511.81005859375')>,
#  < BTC_UCD(date='2017-06-05 00:00:00', Close='2686.81005859375')>,
#  < BTC_UCD(date='2017-06-06 00:00:00', Close='2863.199951171875')>,
#  < BTC_UCD(date='2017-06-07 00:00:00', Close='2732.159912109375')>,
#  < BTC_UCD(date='2017-06-08 00:00:00', Close='2805.6201171875')>,
#  < BTC_UCD(date='2017-06-09 00:00:00', Close='2823.81005859375')>,
#  < BTC_UCD(date='2017-06-10 00:00:00', Close='2947.7099609375')>,
#  < BTC_UCD(date='2017-06-11 00:00:00', Close='2958.110107421875')>,
#  < BTC_UCD(date='2017-06-12 00:00:00', Close='2659.6298828125')>,
#  < BTC_UCD(date='2017-06-13 00:00:00', Close='2717.02001953125')>,
#  < BTC_UCD(date='2017-06-14 00:00:00', Close='2506.3701171875')>,
#  < BTC_UCD(date='2017-06-15 00:00:00', Close='2464.580078125')>,
#  < BTC_UCD(date='2017-06-16 00:00:00', Close='2518.56005859375')>,
#  < BTC_UCD(date='2017-06-17 00:00:00', Close='2655.8798828125')>,
#  < BTC_UCD(date='2017-06-18 00:00:00', Close='2548.2900390625')>,
#  < BTC_UCD(date='2017-06-19 00:00:00', Close='2589.60009765625')>,
#  < BTC_UCD(date='2017-06-20 00:00:00', Close='2721.7900390625')>,
#  < BTC_UCD(date='2017-06-21 00:00:00', Close='2689.10009765625')>,
#  < BTC_UCD(date='2017-06-22 00:00:00', Close='2705.409912109375')>,
#  < BTC_UCD(date='2017-06-23 00:00:00', Close='2744.909912109375')>,
#  < BTC_UCD(date='2017-06-24 00:00:00', Close='2608.719970703125')>,
#  < BTC_UCD(date='2017-06-25 00:00:00', Close='2589.409912109375')>,
#  < BTC_UCD(date='2017-06-26 00:00:00', Close='2478.449951171875')>,
#  < BTC_UCD(date='2017-06-27 00:00:00', Close='2552.449951171875')>,
#  < BTC_UCD(date='2017-06-28 00:00:00', Close='2574.7900390625')>,
#  < BTC_UCD(date='2017-06-29 00:00:00', Close='2539.320068359375')>,
#  < BTC_UCD(date='2017-06-30 00:00:00', Close='2480.840087890625')>,
#  < BTC_UCD(date='2017-07-01 00:00:00', Close='2434.550048828125')>,
#  < BTC_UCD(date='2017-07-02 00:00:00', Close='2506.469970703125')>,
#  < BTC_UCD(date='2017-07-03 00:00:00', Close='2564.06005859375')>,
#  < BTC_UCD(date='2017-07-04 00:00:00', Close='2601.639892578125')>,
#  < BTC_UCD(date='2017-07-05 00:00:00', Close='2601.989990234375')>,
#  < BTC_UCD(date='2017-07-06 00:00:00', Close='2608.56005859375')>,
#  < BTC_UCD(date='2017-07-07 00:00:00', Close='2518.659912109375')>,
#  < BTC_UCD(date='2017-07-08 00:00:00', Close='2571.340087890625')>,
#  < BTC_UCD(date='2017-07-09 00:00:00', Close='2518.43994140625')>,
#  < BTC_UCD(date='2017-07-10 00:00:00', Close='2372.56005859375')>,
#  < BTC_UCD(date='2017-07-11 00:00:00', Close='2337.7900390625')>,
#  < BTC_UCD(date='2017-07-12 00:00:00', Close='2398.840087890625')>,
#  < BTC_UCD(date='2017-07-13 00:00:00', Close='2357.89990234375')>,
#  < BTC_UCD(date='2017-07-14 00:00:00', Close='2233.340087890625')>,
#  < BTC_UCD(date='2017-07-15 00:00:00', Close='1998.8599853515625')>,
#  < BTC_UCD(date='2017-07-16 00:00:00', Close='1929.8199462890625')>,
#  < BTC_UCD(date='2017-07-17 00:00:00', Close='2228.409912109375')>,
#  < BTC_UCD(date='2017-07-18 00:00:00', Close='2318.8798828125')>,
#  < BTC_UCD(date='2017-07-19 00:00:00', Close='2273.429931640625')>,
#  < BTC_UCD(date='2017-07-20 00:00:00', Close='2817.60009765625')>,
#  < BTC_UCD(date='2017-07-21 00:00:00', Close='2667.760009765625')>,
#  < BTC_UCD(date='2017-07-22 00:00:00', Close='2810.1201171875')>,
#  < BTC_UCD(date='2017-07-23 00:00:00', Close='2730.39990234375')>,
#  < BTC_UCD(date='2017-07-24 00:00:00', Close='2754.860107421875')>,
#  < BTC_UCD(date='2017-07-25 00:00:00', Close='2576.47998046875')>,
#  < BTC_UCD(date='2017-07-26 00:00:00', Close='2529.449951171875')>,
#  < BTC_UCD(date='2017-07-27 00:00:00', Close='2671.780029296875')>,
#  < BTC_UCD(date='2017-07-28 00:00:00', Close='2809.010009765625')>,
#  < BTC_UCD(date='2017-07-29 00:00:00', Close='2726.449951171875')>,
#  < BTC_UCD(date='2017-07-30 00:00:00', Close='2757.179931640625')>,
#  < BTC_UCD(date='2017-07-31 00:00:00', Close='2875.340087890625')>,
#  < BTC_UCD(date='2017-08-01 00:00:00', Close='2718.260009765625')>,
#  < BTC_UCD(date='2017-08-02 00:00:00', Close='2710.669921875')>,
#  < BTC_UCD(date='2017-08-03 00:00:00', Close='2804.72998046875')>,
#  < BTC_UCD(date='2017-08-04 00:00:00', Close='2895.889892578125')>,
#  < BTC_UCD(date='2017-08-05 00:00:00', Close='3252.909912109375')>,
#  < BTC_UCD(date='2017-08-06 00:00:00', Close='3213.93994140625')>,
#  < BTC_UCD(date='2017-08-07 00:00:00', Close='3378.93994140625')>,
#  < BTC_UCD(date='2017-08-08 00:00:00', Close='3419.93994140625')>,
#  < BTC_UCD(date='2017-08-09 00:00:00', Close='3342.469970703125')>,
#  < BTC_UCD(date='2017-08-10 00:00:00', Close='3381.280029296875')>,
#  < BTC_UCD(date='2017-08-11 00:00:00', Close='3650.6201171875')>,
#  < BTC_UCD(date='2017-08-12 00:00:00', Close='3884.7099609375')>,
#  < BTC_UCD(date='2017-08-13 00:00:00', Close='4073.260009765625')>,
#  < BTC_UCD(date='2017-08-14 00:00:00', Close='4325.1298828125')>,
#  < BTC_UCD(date='2017-08-15 00:00:00', Close='4181.93017578125')>,
#  < BTC_UCD(date='2017-08-16 00:00:00', Close='4376.6298828125')>,
#  < BTC_UCD(date='2017-08-17 00:00:00', Close='4331.68994140625')>,
#  < BTC_UCD(date='2017-08-18 00:00:00', Close='4160.6201171875')>,
#  < BTC_UCD(date='2017-08-19 00:00:00', Close='4193.7001953125')>,
#  < BTC_UCD(date='2017-08-20 00:00:00', Close='4087.659912109375')>,
#  < BTC_UCD(date='2017-08-21 00:00:00', Close='4001.739990234375')>,
#  < BTC_UCD(date='2017-08-22 00:00:00', Close='4100.52001953125')>,
#  < BTC_UCD(date='2017-08-23 00:00:00', Close='4151.52001953125')>,
#  < BTC_UCD(date='2017-08-24 00:00:00', Close='4334.68017578125')>,
#  < BTC_UCD(date='2017-08-25 00:00:00', Close='4371.60009765625')>,
#  < BTC_UCD(date='2017-08-26 00:00:00', Close='4352.39990234375')>,
#  < BTC_UCD(date='2017-08-27 00:00:00', Close='4382.8798828125')>,
#  < BTC_UCD(date='2017-08-28 00:00:00', Close='4382.66015625')>,
#  < BTC_UCD(date='2017-08-29 00:00:00', Close='4579.02001953125')>,
#  < BTC_UCD(date='2017-08-30 00:00:00', Close='4565.2998046875')>,
#  < BTC_UCD(date='2017-08-31 00:00:00', Close='4703.39013671875')>,
#  < BTC_UCD(date='2017-09-01 00:00:00', Close='4892.009765625')>,
#  < BTC_UCD(date='2017-09-02 00:00:00', Close='4578.77001953125')>,
#  < BTC_UCD(date='2017-09-03 00:00:00', Close='4582.9599609375')>,
#  < BTC_UCD(date='2017-09-04 00:00:00', Close='4236.31005859375')>,
#  < BTC_UCD(date='2017-09-05 00:00:00', Close='4376.52978515625')>,
#  < BTC_UCD(date='2017-09-06 00:00:00', Close='4597.1201171875')>,
#  < BTC_UCD(date='2017-09-07 00:00:00', Close='4599.8798828125')>,
#  < BTC_UCD(date='2017-09-08 00:00:00', Close='4228.75')>,
#  < BTC_UCD(date='2017-09-09 00:00:00', Close='4226.06005859375')>,
#  < BTC_UCD(date='2017-09-10 00:00:00', Close='4122.93994140625')>,
#  < BTC_UCD(date='2017-09-11 00:00:00', Close='4161.27001953125')>,
#  < BTC_UCD(date='2017-09-12 00:00:00', Close='4130.81005859375')>,
#  < BTC_UCD(date='2017-09-13 00:00:00', Close='3882.590087890625')>,
#  < BTC_UCD(date='2017-09-14 00:00:00', Close='3154.949951171875')>,
#  < BTC_UCD(date='2017-09-15 00:00:00', Close='3637.52001953125')>,
#  < BTC_UCD(date='2017-09-16 00:00:00', Close='3625.0400390625')>,
#  < BTC_UCD(date='2017-09-17 00:00:00', Close='3582.8798828125')>,
#  < BTC_UCD(date='2017-09-18 00:00:00', Close='4065.199951171875')>,
#  < BTC_UCD(date='2017-09-19 00:00:00', Close='3924.969970703125')>,
#  < BTC_UCD(date='2017-09-20 00:00:00', Close='3905.949951171875')>,
#  < BTC_UCD(date='2017-09-21 00:00:00', Close='3631.0400390625')>,
#  < BTC_UCD(date='2017-09-22 00:00:00', Close='3630.699951171875')>,
#  < BTC_UCD(date='2017-09-23 00:00:00', Close='3792.39990234375')>,
#  < BTC_UCD(date='2017-09-24 00:00:00', Close='3682.840087890625')>,
#  < BTC_UCD(date='2017-09-25 00:00:00', Close='3926.070068359375')>,
#  < BTC_UCD(date='2017-09-26 00:00:00', Close='3892.35009765625')>,
#  ...]

# %% [markdown]
# ## Insert Data into Database:

# %%
with SessionLocal() as db:
    # Using list of model objects
    db.add_all(data_objects)

    db.commit()  # Commit changes to the database
